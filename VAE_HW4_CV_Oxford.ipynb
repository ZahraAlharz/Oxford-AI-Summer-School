# %% [markdown]
# <a href="https://colab.research.google.com/github/ZahraAlharz/Oxford-AI-Summer-School/blob/main/VAE_HW4_CV_Oxford.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Implement  Variational Autoencoder for Image Attribute Manipulation with CelebA
# The objective of this homework is to implement a Variational Autoencoder (VAE) in PyTorch and use it for image attribute manipulation on the CelebA dataset.
#
# For example: Change hair color or add glasses
#
# ##Dataset:
# CelebFaces Attributes Dataset (CelebA) is a large-scale face attributes dataset with more than 200K celebrity images, each with 40 attribute annotations. The images in this dataset cover large pose variations and background clutter. CelebA has large diversities, large quantities, and rich annotations, including
#
# *   10,177 number of identities,
# *   202,599 number of face images, and
# *   5 landmark locations, 40 binary attributes annotations per image.

# %% [markdown]
# ##Tasks:
#
# 1. Implement a conditional VAE (CVAE) that can manipulate image attributes.
# 2. Train the VAE on the CelebA dataset. Hint: VAE will be conditional VAE
# 3. Manipulate specific attributes of the images.
# 4. Evaluate and visualize the results.

# %%
import os
import torch
import torchvision
from torchvision import transforms, utils
from torchvision.datasets import CelebA
from torch import optim

from torch.utils.data import DataLoader, Dataset
from PIL import Image
import matplotlib.pyplot as plt
from google.colab import drive

# %%
# Define the transformation for the dataset
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize images to 64x64
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Download and load the CelebA dataset
#dataset = CelebA(root='./data', split='train', download=True, transform=transform)
#dataloader = torch.utils.data.DataLoader(dataset, batch_size=64, shuffle=True)

# %% [markdown]
# # Download the Datset on the Drive

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Change directory to CelebA dataset location
# %cd /content/drive/My\Drive/CelebA
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/CelebA

# %% [markdown]
# ## Unzip the Images file

# %%
#!unzip img_align_celeba.zip -d img_align_celeba
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: img_align_celeba/img_align_celeba/197600.jpg
#  extracting: img_align_celeba/img_align_celeba/197601.jpg
#  extracting: img_align_celeba/img_align_celeba/197602.jpg
#  extracting: img_align_celeba/img_align_celeba/197603.jpg
#  extracting: img_align_celeba/img_align_celeba/197604.jpg
#  extracting: img_align_celeba/img_align_celeba/197605.jpg
#  extracting: img_align_celeba/img_align_celeba/197606.jpg
#  extracting: img_align_celeba/img_align_celeba/197607.jpg
#  extracting: img_align_celeba/img_align_celeba/197608.jpg
#  extracting: img_align_celeba/img_align_celeba/197609.jpg
#  extracting: img_align_celeba/img_align_celeba/197610.jpg
#  extracting: img_align_celeba/img_align_celeba/197611.jpg
#  extracting: img_align_celeba/img_align_celeba/197612.jpg
#  extracting: img_align_celeba/img_align_celeba/197613.jpg
#  extracting: img_align_celeba/img_align_celeba/197614.jpg
#  extracting: img_align_celeba/img_align_celeba/197615.jpg
#  extracting: img_align_celeba/img_align_celeba/197616.jpg
#  extracting: img_align_celeba/img_align_celeba/197617.jpg
#  extracting: img_align_celeba/img_align_celeba/197618.jpg
#  extracting: img_align_celeba/img_align_celeba/197619.jpg
#  extracting: img_align_celeba/img_align_celeba/197620.jpg
#  extracting: img_align_celeba/img_align_celeba/197621.jpg
#  extracting: img_align_celeba/img_align_celeba/197622.jpg
#  extracting: img_align_celeba/img_align_celeba/197623.jpg
#  extracting: img_align_celeba/img_align_celeba/197624.jpg
#  extracting: img_align_celeba/img_align_celeba/197625.jpg
#  extracting: img_align_celeba/img_align_celeba/197626.jpg
#  extracting: img_align_celeba/img_align_celeba/197627.jpg
#  extracting: img_align_celeba/img_align_celeba/197628.jpg
#  extracting: img_align_celeba/img_align_celeba/197629.jpg
#  extracting: img_align_celeba/img_align_celeba/197630.jpg
#  extracting: img_align_celeba/img_align_celeba/197631.jpg
#  extracting: img_align_celeba/img_align_celeba/197632.jpg
#  extracting: img_align_celeba/img_align_celeba/197633.jpg
#  extracting: img_align_celeba/img_align_celeba/197634.jpg
#  extracting: img_align_celeba/img_align_celeba/197635.jpg
#  extracting: img_align_celeba/img_align_celeba/197636.jpg
#  extracting: img_align_celeba/img_align_celeba/197637.jpg
#  extracting: img_align_celeba/img_align_celeba/197638.jpg
#  extracting: img_align_celeba/img_align_celeba/197639.jpg
#  extracting: img_align_celeba/img_align_celeba/197640.jpg
#  extracting: img_align_celeba/img_align_celeba/197641.jpg
#  extracting: img_align_celeba/img_align_celeba/197642.jpg
#  extracting: img_align_celeba/img_align_celeba/197643.jpg
#  extracting: img_align_celeba/img_align_celeba/197644.jpg
#  extracting: img_align_celeba/img_align_celeba/197645.jpg
#  extracting: img_align_celeba/img_align_celeba/197646.jpg
#  extracting: img_align_celeba/img_align_celeba/197647.jpg
#  extracting: img_align_celeba/img_align_celeba/197648.jpg
#  extracting: img_align_celeba/img_align_celeba/197649.jpg
#  extracting: img_align_celeba/img_align_celeba/197650.jpg
#  extracting: img_align_celeba/img_align_celeba/197651.jpg
#  extracting: img_align_celeba/img_align_celeba/197652.jpg
#  extracting: img_align_celeba/img_align_celeba/197653.jpg
#  extracting: img_align_celeba/img_align_celeba/197654.jpg
#  extracting: img_align_celeba/img_align_celeba/197655.jpg
#  extracting: img_align_celeba/img_align_celeba/197656.jpg
#  extracting: img_align_celeba/img_align_celeba/197657.jpg
#  extracting: img_align_celeba/img_align_celeba/197658.jpg
#  extracting: img_align_celeba/img_align_celeba/197659.jpg
#  extracting: img_align_celeba/img_align_celeba/197660.jpg
#  extracting: img_align_celeba/img_align_celeba/197661.jpg
#  extracting: img_align_celeba/img_align_celeba/197662.jpg
#  extracting: img_align_celeba/img_align_celeba/197663.jpg
#  extracting: img_align_celeba/img_align_celeba/197664.jpg
#  extracting: img_align_celeba/img_align_celeba/197665.jpg
#  extracting: img_align_celeba/img_align_celeba/197666.jpg
#  extracting: img_align_celeba/img_align_celeba/197667.jpg
#  extracting: img_align_celeba/img_align_celeba/197668.jpg
#  extracting: img_align_celeba/img_align_celeba/197669.jpg
#  extracting: img_align_celeba/img_align_celeba/197670.jpg
#  extracting: img_align_celeba/img_align_celeba/197671.jpg
#  extracting: img_align_celeba/img_align_celeba/197672.jpg
#  extracting: img_align_celeba/img_align_celeba/197673.jpg
#  extracting: img_align_celeba/img_align_celeba/197674.jpg
#  extracting: img_align_celeba/img_align_celeba/197675.jpg
#  extracting: img_align_celeba/img_align_celeba/197676.jpg
#  extracting: img_align_celeba/img_align_celeba/197677.jpg
#  extracting: img_align_celeba/img_align_celeba/197678.jpg
#  extracting: img_align_celeba/img_align_celeba/197679.jpg
#  extracting: img_align_celeba/img_align_celeba/197680.jpg
#  extracting: img_align_celeba/img_align_celeba/197681.jpg
#  extracting: img_align_celeba/img_align_celeba/197682.jpg
#  extracting: img_align_celeba/img_align_celeba/197683.jpg
#  extracting: img_align_celeba/img_align_celeba/197684.jpg
#  extracting: img_align_celeba/img_align_celeba/197685.jpg
#  extracting: img_align_celeba/img_align_celeba/197686.jpg
#  extracting: img_align_celeba/img_align_celeba/197687.jpg
#  extracting: img_align_celeba/img_align_celeba/197688.jpg
#  extracting: img_align_celeba/img_align_celeba/197689.jpg
#  extracting: img_align_celeba/img_align_celeba/197690.jpg
#  extracting: img_align_celeba/img_align_celeba/197691.jpg
#  extracting: img_align_celeba/img_align_celeba/197692.jpg
#  extracting: img_align_celeba/img_align_celeba/197693.jpg
#  extracting: img_align_celeba/img_align_celeba/197694.jpg
#  extracting: img_align_celeba/img_align_celeba/197695.jpg
#  extracting: img_align_celeba/img_align_celeba/197696.jpg
#  extracting: img_align_celeba/img_align_celeba/197697.jpg
#  extracting: img_align_celeba/img_align_celeba/197698.jpg
#  extracting: img_align_celeba/img_align_celeba/197699.jpg
#  extracting: img_align_celeba/img_align_celeba/197700.jpg
#  extracting: img_align_celeba/img_align_celeba/197701.jpg
#  extracting: img_align_celeba/img_align_celeba/197702.jpg
#  extracting: img_align_celeba/img_align_celeba/197703.jpg
#  extracting: img_align_celeba/img_align_celeba/197704.jpg
#  extracting: img_align_celeba/img_align_celeba/197705.jpg
#  extracting: img_align_celeba/img_align_celeba/197706.jpg
#  extracting: img_align_celeba/img_align_celeba/197707.jpg
#  extracting: img_align_celeba/img_align_celeba/197708.jpg
#  extracting: img_align_celeba/img_align_celeba/197709.jpg
#  extracting: img_align_celeba/img_align_celeba/197710.jpg
#  extracting: img_align_celeba/img_align_celeba/197711.jpg
#  extracting: img_align_celeba/img_align_celeba/197712.jpg
#  extracting: img_align_celeba/img_align_celeba/197713.jpg
#  extracting: img_align_celeba/img_align_celeba/197714.jpg
#  extracting: img_align_celeba/img_align_celeba/197715.jpg
#  extracting: img_align_celeba/img_align_celeba/197716.jpg
#  extracting: img_align_celeba/img_align_celeba/197717.jpg
#  extracting: img_align_celeba/img_align_celeba/197718.jpg
#  extracting: img_align_celeba/img_align_celeba/197719.jpg
#  extracting: img_align_celeba/img_align_celeba/197720.jpg
#  extracting: img_align_celeba/img_align_celeba/197721.jpg
#  extracting: img_align_celeba/img_align_celeba/197722.jpg
#  extracting: img_align_celeba/img_align_celeba/197723.jpg
#  extracting: img_align_celeba/img_align_celeba/197724.jpg
#  extracting: img_align_celeba/img_align_celeba/197725.jpg
#  extracting: img_align_celeba/img_align_celeba/197726.jpg
#  extracting: img_align_celeba/img_align_celeba/197727.jpg
#  extracting: img_align_celeba/img_align_celeba/197728.jpg
#  extracting: img_align_celeba/img_align_celeba/197729.jpg
#  extracting: img_align_celeba/img_align_celeba/197730.jpg
#  extracting: img_align_celeba/img_align_celeba/197731.jpg
#  extracting: img_align_celeba/img_align_celeba/197732.jpg
#  extracting: img_align_celeba/img_align_celeba/197733.jpg
#  extracting: img_align_celeba/img_align_celeba/197734.jpg
#  extracting: img_align_celeba/img_align_celeba/197735.jpg
#  extracting: img_align_celeba/img_align_celeba/197736.jpg
#  extracting: img_align_celeba/img_align_celeba/197737.jpg
#  extracting: img_align_celeba/img_align_celeba/197738.jpg
#  extracting: img_align_celeba/img_align_celeba/197739.jpg
#  extracting: img_align_celeba/img_align_celeba/197740.jpg
#  extracting: img_align_celeba/img_align_celeba/197741.jpg
#  extracting: img_align_celeba/img_align_celeba/197742.jpg
#  extracting: img_align_celeba/img_align_celeba/197743.jpg
#  extracting: img_align_celeba/img_align_celeba/197744.jpg
#  extracting: img_align_celeba/img_align_celeba/197745.jpg
#  extracting: img_align_celeba/img_align_celeba/197746.jpg
#  extracting: img_align_celeba/img_align_celeba/197747.jpg
#  extracting: img_align_celeba/img_align_celeba/197748.jpg
#  extracting: img_align_celeba/img_align_celeba/197749.jpg
#  extracting: img_align_celeba/img_align_celeba/197750.jpg
#  extracting: img_align_celeba/img_align_celeba/197751.jpg
#  extracting: img_align_celeba/img_align_celeba/197752.jpg
#  extracting: img_align_celeba/img_align_celeba/197753.jpg
#  extracting: img_align_celeba/img_align_celeba/197754.jpg
#  extracting: img_align_celeba/img_align_celeba/197755.jpg
#  extracting: img_align_celeba/img_align_celeba/197756.jpg
#  extracting: img_align_celeba/img_align_celeba/197757.jpg
#  extracting: img_align_celeba/img_align_celeba/197758.jpg
#  extracting: img_align_celeba/img_align_celeba/197759.jpg
#  extracting: img_align_celeba/img_align_celeba/197760.jpg
#  extracting: img_align_celeba/img_align_celeba/197761.jpg
#  extracting: img_align_celeba/img_align_celeba/197762.jpg
#  extracting: img_align_celeba/img_align_celeba/197763.jpg
#  extracting: img_align_celeba/img_align_celeba/197764.jpg
#  extracting: img_align_celeba/img_align_celeba/197765.jpg
#  extracting: img_align_celeba/img_align_celeba/197766.jpg
#  extracting: img_align_celeba/img_align_celeba/197767.jpg
#  extracting: img_align_celeba/img_align_celeba/197768.jpg
#  extracting: img_align_celeba/img_align_celeba/197769.jpg
#  extracting: img_align_celeba/img_align_celeba/197770.jpg
#  extracting: img_align_celeba/img_align_celeba/197771.jpg
#  extracting: img_align_celeba/img_align_celeba/197772.jpg
#  extracting: img_align_celeba/img_align_celeba/197773.jpg
#  extracting: img_align_celeba/img_align_celeba/197774.jpg
#  extracting: img_align_celeba/img_align_celeba/197775.jpg
#  extracting: img_align_celeba/img_align_celeba/197776.jpg
#  extracting: img_align_celeba/img_align_celeba/197777.jpg
#  extracting: img_align_celeba/img_align_celeba/197778.jpg
#  extracting: img_align_celeba/img_align_celeba/197779.jpg
#  extracting: img_align_celeba/img_align_celeba/197780.jpg
#  extracting: img_align_celeba/img_align_celeba/197781.jpg
#  extracting: img_align_celeba/img_align_celeba/197782.jpg
#  extracting: img_align_celeba/img_align_celeba/197783.jpg
#  extracting: img_align_celeba/img_align_celeba/197784.jpg
#  extracting: img_align_celeba/img_align_celeba/197785.jpg
#  extracting: img_align_celeba/img_align_celeba/197786.jpg
#  extracting: img_align_celeba/img_align_celeba/197787.jpg
#  extracting: img_align_celeba/img_align_celeba/197788.jpg
#  extracting: img_align_celeba/img_align_celeba/197789.jpg
#  extracting: img_align_celeba/img_align_celeba/197790.jpg
#  extracting: img_align_celeba/img_align_celeba/197791.jpg
#  extracting: img_align_celeba/img_align_celeba/197792.jpg
#  extracting: img_align_celeba/img_align_celeba/197793.jpg
#  extracting: img_align_celeba/img_align_celeba/197794.jpg
#  extracting: img_align_celeba/img_align_celeba/197795.jpg
#  extracting: img_align_celeba/img_align_celeba/197796.jpg
#  extracting: img_align_celeba/img_align_celeba/197797.jpg
#  extracting: img_align_celeba/img_align_celeba/197798.jpg
#  extracting: img_align_celeba/img_align_celeba/197799.jpg
#  extracting: img_align_celeba/img_align_celeba/197800.jpg
#  extracting: img_align_celeba/img_align_celeba/197801.jpg
#  extracting: img_align_celeba/img_align_celeba/197802.jpg
#  extracting: img_align_celeba/img_align_celeba/197803.jpg
#  extracting: img_align_celeba/img_align_celeba/197804.jpg
#  extracting: img_align_celeba/img_align_celeba/197805.jpg
#  extracting: img_align_celeba/img_align_celeba/197806.jpg
#  extracting: img_align_celeba/img_align_celeba/197807.jpg
#  extracting: img_align_celeba/img_align_celeba/197808.jpg
#  extracting: img_align_celeba/img_align_celeba/197809.jpg
#  extracting: img_align_celeba/img_align_celeba/197810.jpg
#  extracting: img_align_celeba/img_align_celeba/197811.jpg
#  extracting: img_align_celeba/img_align_celeba/197812.jpg
#  extracting: img_align_celeba/img_align_celeba/197813.jpg
#  extracting: img_align_celeba/img_align_celeba/197814.jpg
#  extracting: img_align_celeba/img_align_celeba/197815.jpg
#  extracting: img_align_celeba/img_align_celeba/197816.jpg
#  extracting: img_align_celeba/img_align_celeba/197817.jpg
#  extracting: img_align_celeba/img_align_celeba/197818.jpg
#  extracting: img_align_celeba/img_align_celeba/197819.jpg
#  extracting: img_align_celeba/img_align_celeba/197820.jpg
#  extracting: img_align_celeba/img_align_celeba/197821.jpg
#  extracting: img_align_celeba/img_align_celeba/197822.jpg
#  extracting: img_align_celeba/img_align_celeba/197823.jpg
#  extracting: img_align_celeba/img_align_celeba/197824.jpg
#  extracting: img_align_celeba/img_align_celeba/197825.jpg
#  extracting: img_align_celeba/img_align_celeba/197826.jpg
#  extracting: img_align_celeba/img_align_celeba/197827.jpg
#  extracting: img_align_celeba/img_align_celeba/197828.jpg
#  extracting: img_align_celeba/img_align_celeba/197829.jpg
#  extracting: img_align_celeba/img_align_celeba/197830.jpg
#  extracting: img_align_celeba/img_align_celeba/197831.jpg
#  extracting: img_align_celeba/img_align_celeba/197832.jpg
#  extracting: img_align_celeba/img_align_celeba/197833.jpg
#  extracting: img_align_celeba/img_align_celeba/197834.jpg
#  extracting: img_align_celeba/img_align_celeba/197835.jpg
#  extracting: img_align_celeba/img_align_celeba/197836.jpg
#  extracting: img_align_celeba/img_align_celeba/197837.jpg
#  extracting: img_align_celeba/img_align_celeba/197838.jpg
#  extracting: img_align_celeba/img_align_celeba/197839.jpg
#  extracting: img_align_celeba/img_align_celeba/197840.jpg
#  extracting: img_align_celeba/img_align_celeba/197841.jpg
#  extracting: img_align_celeba/img_align_celeba/197842.jpg
#  extracting: img_align_celeba/img_align_celeba/197843.jpg
#  extracting: img_align_celeba/img_align_celeba/197844.jpg
#  extracting: img_align_celeba/img_align_celeba/197845.jpg
#  extracting: img_align_celeba/img_align_celeba/197846.jpg
#  extracting: img_align_celeba/img_align_celeba/197847.jpg
#  extracting: img_align_celeba/img_align_celeba/197848.jpg
#  extracting: img_align_celeba/img_align_celeba/197849.jpg
#  extracting: img_align_celeba/img_align_celeba/197850.jpg
#  extracting: img_align_celeba/img_align_celeba/197851.jpg
#  extracting: img_align_celeba/img_align_celeba/197852.jpg
#  extracting: img_align_celeba/img_align_celeba/197853.jpg
#  extracting: img_align_celeba/img_align_celeba/197854.jpg
#  extracting: img_align_celeba/img_align_celeba/197855.jpg
#  extracting: img_align_celeba/img_align_celeba/197856.jpg
#  extracting: img_align_celeba/img_align_celeba/197857.jpg
#  extracting: img_align_celeba/img_align_celeba/197858.jpg
#  extracting: img_align_celeba/img_align_celeba/197859.jpg
#  extracting: img_align_celeba/img_align_celeba/197860.jpg
#  extracting: img_align_celeba/img_align_celeba/197861.jpg
#  extracting: img_align_celeba/img_align_celeba/197862.jpg
#  extracting: img_align_celeba/img_align_celeba/197863.jpg
#  extracting: img_align_celeba/img_align_celeba/197864.jpg
#  extracting: img_align_celeba/img_align_celeba/197865.jpg
#  extracting: img_align_celeba/img_align_celeba/197866.jpg
#  extracting: img_align_celeba/img_align_celeba/197867.jpg
#  extracting: img_align_celeba/img_align_celeba/197868.jpg
#  extracting: img_align_celeba/img_align_celeba/197869.jpg
#  extracting: img_align_celeba/img_align_celeba/197870.jpg
#  extracting: img_align_celeba/img_align_celeba/197871.jpg
#  extracting: img_align_celeba/img_align_celeba/197872.jpg
#  extracting: img_align_celeba/img_align_celeba/197873.jpg
#  extracting: img_align_celeba/img_align_celeba/197874.jpg
#  extracting: img_align_celeba/img_align_celeba/197875.jpg
#  extracting: img_align_celeba/img_align_celeba/197876.jpg
#  extracting: img_align_celeba/img_align_celeba/197877.jpg
#  extracting: img_align_celeba/img_align_celeba/197878.jpg
#  extracting: img_align_celeba/img_align_celeba/197879.jpg
#  extracting: img_align_celeba/img_align_celeba/197880.jpg
#  extracting: img_align_celeba/img_align_celeba/197881.jpg
#  extracting: img_align_celeba/img_align_celeba/197882.jpg
#  extracting: img_align_celeba/img_align_celeba/197883.jpg
#  extracting: img_align_celeba/img_align_celeba/197884.jpg
#  extracting: img_align_celeba/img_align_celeba/197885.jpg
#  extracting: img_align_celeba/img_align_celeba/197886.jpg
#  extracting: img_align_celeba/img_align_celeba/197887.jpg
#  extracting: img_align_celeba/img_align_celeba/197888.jpg
#  extracting: img_align_celeba/img_align_celeba/197889.jpg
#  extracting: img_align_celeba/img_align_celeba/197890.jpg
#  extracting: img_align_celeba/img_align_celeba/197891.jpg
#  extracting: img_align_celeba/img_align_celeba/197892.jpg
#  extracting: img_align_celeba/img_align_celeba/197893.jpg
#  extracting: img_align_celeba/img_align_celeba/197894.jpg
#  extracting: img_align_celeba/img_align_celeba/197895.jpg
#  extracting: img_align_celeba/img_align_celeba/197896.jpg
#  extracting: img_align_celeba/img_align_celeba/197897.jpg
#  extracting: img_align_celeba/img_align_celeba/197898.jpg
#  extracting: img_align_celeba/img_align_celeba/197899.jpg
#  extracting: img_align_celeba/img_align_celeba/197900.jpg
#  extracting: img_align_celeba/img_align_celeba/197901.jpg
#  extracting: img_align_celeba/img_align_celeba/197902.jpg
#  extracting: img_align_celeba/img_align_celeba/197903.jpg
#  extracting: img_align_celeba/img_align_celeba/197904.jpg
#  extracting: img_align_celeba/img_align_celeba/197905.jpg
#  extracting: img_align_celeba/img_align_celeba/197906.jpg
#  extracting: img_align_celeba/img_align_celeba/197907.jpg
#  extracting: img_align_celeba/img_align_celeba/197908.jpg
#  extracting: img_align_celeba/img_align_celeba/197909.jpg
#  extracting: img_align_celeba/img_align_celeba/197910.jpg
#  extracting: img_align_celeba/img_align_celeba/197911.jpg
#  extracting: img_align_celeba/img_align_celeba/197912.jpg
#  extracting: img_align_celeba/img_align_celeba/197913.jpg
#  extracting: img_align_celeba/img_align_celeba/197914.jpg
#  extracting: img_align_celeba/img_align_celeba/197915.jpg
#  extracting: img_align_celeba/img_align_celeba/197916.jpg
#  extracting: img_align_celeba/img_align_celeba/197917.jpg
#  extracting: img_align_celeba/img_align_celeba/197918.jpg
#  extracting: img_align_celeba/img_align_celeba/197919.jpg
#  extracting: img_align_celeba/img_align_celeba/197920.jpg
#  extracting: img_align_celeba/img_align_celeba/197921.jpg
#  extracting: img_align_celeba/img_align_celeba/197922.jpg
#  extracting: img_align_celeba/img_align_celeba/197923.jpg
#  extracting: img_align_celeba/img_align_celeba/197924.jpg
#  extracting: img_align_celeba/img_align_celeba/197925.jpg
#  extracting: img_align_celeba/img_align_celeba/197926.jpg
#  extracting: img_align_celeba/img_align_celeba/197927.jpg
#  extracting: img_align_celeba/img_align_celeba/197928.jpg
#  extracting: img_align_celeba/img_align_celeba/197929.jpg
#  extracting: img_align_celeba/img_align_celeba/197930.jpg
#  extracting: img_align_celeba/img_align_celeba/197931.jpg
#  extracting: img_align_celeba/img_align_celeba/197932.jpg
#  extracting: img_align_celeba/img_align_celeba/197933.jpg
#  extracting: img_align_celeba/img_align_celeba/197934.jpg
#  extracting: img_align_celeba/img_align_celeba/197935.jpg
#  extracting: img_align_celeba/img_align_celeba/197936.jpg
#  extracting: img_align_celeba/img_align_celeba/197937.jpg
#  extracting: img_align_celeba/img_align_celeba/197938.jpg
#  extracting: img_align_celeba/img_align_celeba/197939.jpg
#  extracting: img_align_celeba/img_align_celeba/197940.jpg
#  extracting: img_align_celeba/img_align_celeba/197941.jpg
#  extracting: img_align_celeba/img_align_celeba/197942.jpg
#  extracting: img_align_celeba/img_align_celeba/197943.jpg
#  extracting: img_align_celeba/img_align_celeba/197944.jpg
#  extracting: img_align_celeba/img_align_celeba/197945.jpg
#  extracting: img_align_celeba/img_align_celeba/197946.jpg
#  extracting: img_align_celeba/img_align_celeba/197947.jpg
#  extracting: img_align_celeba/img_align_celeba/197948.jpg
#  extracting: img_align_celeba/img_align_celeba/197949.jpg
#  extracting: img_align_celeba/img_align_celeba/197950.jpg
#  extracting: img_align_celeba/img_align_celeba/197951.jpg
#  extracting: img_align_celeba/img_align_celeba/197952.jpg
#  extracting: img_align_celeba/img_align_celeba/197953.jpg
#  extracting: img_align_celeba/img_align_celeba/197954.jpg
#  extracting: img_align_celeba/img_align_celeba/197955.jpg
#  extracting: img_align_celeba/img_align_celeba/197956.jpg
#  extracting: img_align_celeba/img_align_celeba/197957.jpg
#  extracting: img_align_celeba/img_align_celeba/197958.jpg
#  extracting: img_align_celeba/img_align_celeba/197959.jpg
#  extracting: img_align_celeba/img_align_celeba/197960.jpg
#  extracting: img_align_celeba/img_align_celeba/197961.jpg
#  extracting: img_align_celeba/img_align_celeba/197962.jpg
#  extracting: img_align_celeba/img_align_celeba/197963.jpg
#  extracting: img_align_celeba/img_align_celeba/197964.jpg
#  extracting: img_align_celeba/img_align_celeba/197965.jpg
#  extracting: img_align_celeba/img_align_celeba/197966.jpg
#  extracting: img_align_celeba/img_align_celeba/197967.jpg
#  extracting: img_align_celeba/img_align_celeba/197968.jpg
#  extracting: img_align_celeba/img_align_celeba/197969.jpg
#  extracting: img_align_celeba/img_align_celeba/197970.jpg
#  extracting: img_align_celeba/img_align_celeba/197971.jpg
#  extracting: img_align_celeba/img_align_celeba/197972.jpg
#  extracting: img_align_celeba/img_align_celeba/197973.jpg
#  extracting: img_align_celeba/img_align_celeba/197974.jpg
#  extracting: img_align_celeba/img_align_celeba/197975.jpg
#  extracting: img_align_celeba/img_align_celeba/197976.jpg
#  extracting: img_align_celeba/img_align_celeba/197977.jpg
#  extracting: img_align_celeba/img_align_celeba/197978.jpg
#  extracting: img_align_celeba/img_align_celeba/197979.jpg
#  extracting: img_align_celeba/img_align_celeba/197980.jpg
#  extracting: img_align_celeba/img_align_celeba/197981.jpg
#  extracting: img_align_celeba/img_align_celeba/197982.jpg
#  extracting: img_align_celeba/img_align_celeba/197983.jpg
#  extracting: img_align_celeba/img_align_celeba/197984.jpg
#  extracting: img_align_celeba/img_align_celeba/197985.jpg
#  extracting: img_align_celeba/img_align_celeba/197986.jpg
#  extracting: img_align_celeba/img_align_celeba/197987.jpg
#  extracting: img_align_celeba/img_align_celeba/197988.jpg
#  extracting: img_align_celeba/img_align_celeba/197989.jpg
#  extracting: img_align_celeba/img_align_celeba/197990.jpg
#  extracting: img_align_celeba/img_align_celeba/197991.jpg
#  extracting: img_align_celeba/img_align_celeba/197992.jpg
#  extracting: img_align_celeba/img_align_celeba/197993.jpg
#  extracting: img_align_celeba/img_align_celeba/197994.jpg
#  extracting: img_align_celeba/img_align_celeba/197995.jpg
#  extracting: img_align_celeba/img_align_celeba/197996.jpg
#  extracting: img_align_celeba/img_align_celeba/197997.jpg
#  extracting: img_align_celeba/img_align_celeba/197998.jpg
#  extracting: img_align_celeba/img_align_celeba/197999.jpg
#  extracting: img_align_celeba/img_align_celeba/198000.jpg
#  extracting: img_align_celeba/img_align_celeba/198001.jpg
#  extracting: img_align_celeba/img_align_celeba/198002.jpg
#  extracting: img_align_celeba/img_align_celeba/198003.jpg
#  extracting: img_align_celeba/img_align_celeba/198004.jpg
#  extracting: img_align_celeba/img_align_celeba/198005.jpg
#  extracting: img_align_celeba/img_align_celeba/198006.jpg
#  extracting: img_align_celeba/img_align_celeba/198007.jpg
#  extracting: img_align_celeba/img_align_celeba/198008.jpg
#  extracting: img_align_celeba/img_align_celeba/198009.jpg
#  extracting: img_align_celeba/img_align_celeba/198010.jpg
#  extracting: img_align_celeba/img_align_celeba/198011.jpg
#  extracting: img_align_celeba/img_align_celeba/198012.jpg
#  extracting: img_align_celeba/img_align_celeba/198013.jpg
#  extracting: img_align_celeba/img_align_celeba/198014.jpg
#  extracting: img_align_celeba/img_align_celeba/198015.jpg
#  extracting: img_align_celeba/img_align_celeba/198016.jpg
#  extracting: img_align_celeba/img_align_celeba/198017.jpg
#  extracting: img_align_celeba/img_align_celeba/198018.jpg
#  extracting: img_align_celeba/img_align_celeba/198019.jpg
#  extracting: img_align_celeba/img_align_celeba/198020.jpg
#  extracting: img_align_celeba/img_align_celeba/198021.jpg
#  extracting: img_align_celeba/img_align_celeba/198022.jpg
#  extracting: img_align_celeba/img_align_celeba/198023.jpg
#  extracting: img_align_celeba/img_align_celeba/198024.jpg
#  extracting: img_align_celeba/img_align_celeba/198025.jpg
#  extracting: img_align_celeba/img_align_celeba/198026.jpg
#  extracting: img_align_celeba/img_align_celeba/198027.jpg
#  extracting: img_align_celeba/img_align_celeba/198028.jpg
#  extracting: img_align_celeba/img_align_celeba/198029.jpg
#  extracting: img_align_celeba/img_align_celeba/198030.jpg
#  extracting: img_align_celeba/img_align_celeba/198031.jpg
#  extracting: img_align_celeba/img_align_celeba/198032.jpg
#  extracting: img_align_celeba/img_align_celeba/198033.jpg
#  extracting: img_align_celeba/img_align_celeba/198034.jpg
#  extracting: img_align_celeba/img_align_celeba/198035.jpg
#  extracting: img_align_celeba/img_align_celeba/198036.jpg
#  extracting: img_align_celeba/img_align_celeba/198037.jpg
#  extracting: img_align_celeba/img_align_celeba/198038.jpg
#  extracting: img_align_celeba/img_align_celeba/198039.jpg
#  extracting: img_align_celeba/img_align_celeba/198040.jpg
#  extracting: img_align_celeba/img_align_celeba/198041.jpg
#  extracting: img_align_celeba/img_align_celeba/198042.jpg
#  extracting: img_align_celeba/img_align_celeba/198043.jpg
#  extracting: img_align_celeba/img_align_celeba/198044.jpg
#  extracting: img_align_celeba/img_align_celeba/198045.jpg
#  extracting: img_align_celeba/img_align_celeba/198046.jpg
#  extracting: img_align_celeba/img_align_celeba/198047.jpg
#  extracting: img_align_celeba/img_align_celeba/198048.jpg
#  extracting: img_align_celeba/img_align_celeba/198049.jpg
#  extracting: img_align_celeba/img_align_celeba/198050.jpg
#  extracting: img_align_celeba/img_align_celeba/198051.jpg
#  extracting: img_align_celeba/img_align_celeba/198052.jpg
#  extracting: img_align_celeba/img_align_celeba/198053.jpg
#  extracting: img_align_celeba/img_align_celeba/198054.jpg
#  extracting: img_align_celeba/img_align_celeba/198055.jpg
#  extracting: img_align_celeba/img_align_celeba/198056.jpg
#  extracting: img_align_celeba/img_align_celeba/198057.jpg
#  extracting: img_align_celeba/img_align_celeba/198058.jpg
#  extracting: img_align_celeba/img_align_celeba/198059.jpg
#  extracting: img_align_celeba/img_align_celeba/198060.jpg
#  extracting: img_align_celeba/img_align_celeba/198061.jpg
#  extracting: img_align_celeba/img_align_celeba/198062.jpg
#  extracting: img_align_celeba/img_align_celeba/198063.jpg
#  extracting: img_align_celeba/img_align_celeba/198064.jpg
#  extracting: img_align_celeba/img_align_celeba/198065.jpg
#  extracting: img_align_celeba/img_align_celeba/198066.jpg
#  extracting: img_align_celeba/img_align_celeba/198067.jpg
#  extracting: img_align_celeba/img_align_celeba/198068.jpg
#  extracting: img_align_celeba/img_align_celeba/198069.jpg
#  extracting: img_align_celeba/img_align_celeba/198070.jpg
#  extracting: img_align_celeba/img_align_celeba/198071.jpg
#  extracting: img_align_celeba/img_align_celeba/198072.jpg
#  extracting: img_align_celeba/img_align_celeba/198073.jpg
#  extracting: img_align_celeba/img_align_celeba/198074.jpg
#  extracting: img_align_celeba/img_align_celeba/198075.jpg
#  extracting: img_align_celeba/img_align_celeba/198076.jpg
#  extracting: img_align_celeba/img_align_celeba/198077.jpg
#  extracting: img_align_celeba/img_align_celeba/198078.jpg
#  extracting: img_align_celeba/img_align_celeba/198079.jpg
#  extracting: img_align_celeba/img_align_celeba/198080.jpg
#  extracting: img_align_celeba/img_align_celeba/198081.jpg
#  extracting: img_align_celeba/img_align_celeba/198082.jpg
#  extracting: img_align_celeba/img_align_celeba/198083.jpg
#  extracting: img_align_celeba/img_align_celeba/198084.jpg
#  extracting: img_align_celeba/img_align_celeba/198085.jpg
#  extracting: img_align_celeba/img_align_celeba/198086.jpg
#  extracting: img_align_celeba/img_align_celeba/198087.jpg
#  extracting: img_align_celeba/img_align_celeba/198088.jpg
#  extracting: img_align_celeba/img_align_celeba/198089.jpg
#  extracting: img_align_celeba/img_align_celeba/198090.jpg
#  extracting: img_align_celeba/img_align_celeba/198091.jpg
#  extracting: img_align_celeba/img_align_celeba/198092.jpg
#  extracting: img_align_celeba/img_align_celeba/198093.jpg
#  extracting: img_align_celeba/img_align_celeba/198094.jpg
#  extracting: img_align_celeba/img_align_celeba/198095.jpg
#  extracting: img_align_celeba/img_align_celeba/198096.jpg
#  extracting: img_align_celeba/img_align_celeba/198097.jpg
#  extracting: img_align_celeba/img_align_celeba/198098.jpg
#  extracting: img_align_celeba/img_align_celeba/198099.jpg
#  extracting: img_align_celeba/img_align_celeba/198100.jpg
#  extracting: img_align_celeba/img_align_celeba/198101.jpg
#  extracting: img_align_celeba/img_align_celeba/198102.jpg
#  extracting: img_align_celeba/img_align_celeba/198103.jpg
#  extracting: img_align_celeba/img_align_celeba/198104.jpg
#  extracting: img_align_celeba/img_align_celeba/198105.jpg
#  extracting: img_align_celeba/img_align_celeba/198106.jpg
#  extracting: img_align_celeba/img_align_celeba/198107.jpg
#  extracting: img_align_celeba/img_align_celeba/198108.jpg
#  extracting: img_align_celeba/img_align_celeba/198109.jpg
#  extracting: img_align_celeba/img_align_celeba/198110.jpg
#  extracting: img_align_celeba/img_align_celeba/198111.jpg
#  extracting: img_align_celeba/img_align_celeba/198112.jpg
#  extracting: img_align_celeba/img_align_celeba/198113.jpg
#  extracting: img_align_celeba/img_align_celeba/198114.jpg
#  extracting: img_align_celeba/img_align_celeba/198115.jpg
#  extracting: img_align_celeba/img_align_celeba/198116.jpg
#  extracting: img_align_celeba/img_align_celeba/198117.jpg
#  extracting: img_align_celeba/img_align_celeba/198118.jpg
#  extracting: img_align_celeba/img_align_celeba/198119.jpg
#  extracting: img_align_celeba/img_align_celeba/198120.jpg
#  extracting: img_align_celeba/img_align_celeba/198121.jpg
#  extracting: img_align_celeba/img_align_celeba/198122.jpg
#  extracting: img_align_celeba/img_align_celeba/198123.jpg
#  extracting: img_align_celeba/img_align_celeba/198124.jpg
#  extracting: img_align_celeba/img_align_celeba/198125.jpg
#  extracting: img_align_celeba/img_align_celeba/198126.jpg
#  extracting: img_align_celeba/img_align_celeba/198127.jpg
#  extracting: img_align_celeba/img_align_celeba/198128.jpg
#  extracting: img_align_celeba/img_align_celeba/198129.jpg
#  extracting: img_align_celeba/img_align_celeba/198130.jpg
#  extracting: img_align_celeba/img_align_celeba/198131.jpg
#  extracting: img_align_celeba/img_align_celeba/198132.jpg
#  extracting: img_align_celeba/img_align_celeba/198133.jpg
#  extracting: img_align_celeba/img_align_celeba/198134.jpg
#  extracting: img_align_celeba/img_align_celeba/198135.jpg
#  extracting: img_align_celeba/img_align_celeba/198136.jpg
#  extracting: img_align_celeba/img_align_celeba/198137.jpg
#  extracting: img_align_celeba/img_align_celeba/198138.jpg
#  extracting: img_align_celeba/img_align_celeba/198139.jpg
#  extracting: img_align_celeba/img_align_celeba/198140.jpg
#  extracting: img_align_celeba/img_align_celeba/198141.jpg
#  extracting: img_align_celeba/img_align_celeba/198142.jpg
#  extracting: img_align_celeba/img_align_celeba/198143.jpg
#  extracting: img_align_celeba/img_align_celeba/198144.jpg
#  extracting: img_align_celeba/img_align_celeba/198145.jpg
#  extracting: img_align_celeba/img_align_celeba/198146.jpg
#  extracting: img_align_celeba/img_align_celeba/198147.jpg
#  extracting: img_align_celeba/img_align_celeba/198148.jpg
#  extracting: img_align_celeba/img_align_celeba/198149.jpg
#  extracting: img_align_celeba/img_align_celeba/198150.jpg
#  extracting: img_align_celeba/img_align_celeba/198151.jpg
#  extracting: img_align_celeba/img_align_celeba/198152.jpg
#  extracting: img_align_celeba/img_align_celeba/198153.jpg
#  extracting: img_align_celeba/img_align_celeba/198154.jpg
#  extracting: img_align_celeba/img_align_celeba/198155.jpg
#  extracting: img_align_celeba/img_align_celeba/198156.jpg
#  extracting: img_align_celeba/img_align_celeba/198157.jpg
#  extracting: img_align_celeba/img_align_celeba/198158.jpg
#  extracting: img_align_celeba/img_align_celeba/198159.jpg
#  extracting: img_align_celeba/img_align_celeba/198160.jpg
#  extracting: img_align_celeba/img_align_celeba/198161.jpg
#  extracting: img_align_celeba/img_align_celeba/198162.jpg
#  extracting: img_align_celeba/img_align_celeba/198163.jpg
#  extracting: img_align_celeba/img_align_celeba/198164.jpg
#  extracting: img_align_celeba/img_align_celeba/198165.jpg
#  extracting: img_align_celeba/img_align_celeba/198166.jpg
#  extracting: img_align_celeba/img_align_celeba/198167.jpg
#  extracting: img_align_celeba/img_align_celeba/198168.jpg
#  extracting: img_align_celeba/img_align_celeba/198169.jpg
#  extracting: img_align_celeba/img_align_celeba/198170.jpg
#  extracting: img_align_celeba/img_align_celeba/198171.jpg
#  extracting: img_align_celeba/img_align_celeba/198172.jpg
#  extracting: img_align_celeba/img_align_celeba/198173.jpg
#  extracting: img_align_celeba/img_align_celeba/198174.jpg
#  extracting: img_align_celeba/img_align_celeba/198175.jpg
#  extracting: img_align_celeba/img_align_celeba/198176.jpg
#  extracting: img_align_celeba/img_align_celeba/198177.jpg
#  extracting: img_align_celeba/img_align_celeba/198178.jpg
#  extracting: img_align_celeba/img_align_celeba/198179.jpg
#  extracting: img_align_celeba/img_align_celeba/198180.jpg
#  extracting: img_align_celeba/img_align_celeba/198181.jpg
#  extracting: img_align_celeba/img_align_celeba/198182.jpg
#  extracting: img_align_celeba/img_align_celeba/198183.jpg
#  extracting: img_align_celeba/img_align_celeba/198184.jpg
#  extracting: img_align_celeba/img_align_celeba/198185.jpg
#  extracting: img_align_celeba/img_align_celeba/198186.jpg
#  extracting: img_align_celeba/img_align_celeba/198187.jpg
#  extracting: img_align_celeba/img_align_celeba/198188.jpg
#  extracting: img_align_celeba/img_align_celeba/198189.jpg
#  extracting: img_align_celeba/img_align_celeba/198190.jpg
#  extracting: img_align_celeba/img_align_celeba/198191.jpg
#  extracting: img_align_celeba/img_align_celeba/198192.jpg
#  extracting: img_align_celeba/img_align_celeba/198193.jpg
#  extracting: img_align_celeba/img_align_celeba/198194.jpg
#  extracting: img_align_celeba/img_align_celeba/198195.jpg
#  extracting: img_align_celeba/img_align_celeba/198196.jpg
#  extracting: img_align_celeba/img_align_celeba/198197.jpg
#  extracting: img_align_celeba/img_align_celeba/198198.jpg
#  extracting: img_align_celeba/img_align_celeba/198199.jpg
#  extracting: img_align_celeba/img_align_celeba/198200.jpg
#  extracting: img_align_celeba/img_align_celeba/198201.jpg
#  extracting: img_align_celeba/img_align_celeba/198202.jpg
#  extracting: img_align_celeba/img_align_celeba/198203.jpg
#  extracting: img_align_celeba/img_align_celeba/198204.jpg
#  extracting: img_align_celeba/img_align_celeba/198205.jpg
#  extracting: img_align_celeba/img_align_celeba/198206.jpg
#  extracting: img_align_celeba/img_align_celeba/198207.jpg
#  extracting: img_align_celeba/img_align_celeba/198208.jpg
#  extracting: img_align_celeba/img_align_celeba/198209.jpg
#  extracting: img_align_celeba/img_align_celeba/198210.jpg
#  extracting: img_align_celeba/img_align_celeba/198211.jpg
#  extracting: img_align_celeba/img_align_celeba/198212.jpg
#  extracting: img_align_celeba/img_align_celeba/198213.jpg
#  extracting: img_align_celeba/img_align_celeba/198214.jpg
#  extracting: img_align_celeba/img_align_celeba/198215.jpg
#  extracting: img_align_celeba/img_align_celeba/198216.jpg
#  extracting: img_align_celeba/img_align_celeba/198217.jpg
#  extracting: img_align_celeba/img_align_celeba/198218.jpg
#  extracting: img_align_celeba/img_align_celeba/198219.jpg
#  extracting: img_align_celeba/img_align_celeba/198220.jpg
#  extracting: img_align_celeba/img_align_celeba/198221.jpg
#  extracting: img_align_celeba/img_align_celeba/198222.jpg
#  extracting: img_align_celeba/img_align_celeba/198223.jpg
#  extracting: img_align_celeba/img_align_celeba/198224.jpg
#  extracting: img_align_celeba/img_align_celeba/198225.jpg
#  extracting: img_align_celeba/img_align_celeba/198226.jpg
#  extracting: img_align_celeba/img_align_celeba/198227.jpg
#  extracting: img_align_celeba/img_align_celeba/198228.jpg
#  extracting: img_align_celeba/img_align_celeba/198229.jpg
#  extracting: img_align_celeba/img_align_celeba/198230.jpg
#  extracting: img_align_celeba/img_align_celeba/198231.jpg
#  extracting: img_align_celeba/img_align_celeba/198232.jpg
#  extracting: img_align_celeba/img_align_celeba/198233.jpg
#  extracting: img_align_celeba/img_align_celeba/198234.jpg
#  extracting: img_align_celeba/img_align_celeba/198235.jpg
#  extracting: img_align_celeba/img_align_celeba/198236.jpg
#  extracting: img_align_celeba/img_align_celeba/198237.jpg
#  extracting: img_align_celeba/img_align_celeba/198238.jpg
#  extracting: img_align_celeba/img_align_celeba/198239.jpg
#  extracting: img_align_celeba/img_align_celeba/198240.jpg
#  extracting: img_align_celeba/img_align_celeba/198241.jpg
#  extracting: img_align_celeba/img_align_celeba/198242.jpg
#  extracting: img_align_celeba/img_align_celeba/198243.jpg
#  extracting: img_align_celeba/img_align_celeba/198244.jpg
#  extracting: img_align_celeba/img_align_celeba/198245.jpg
#  extracting: img_align_celeba/img_align_celeba/198246.jpg
#  extracting: img_align_celeba/img_align_celeba/198247.jpg
#  extracting: img_align_celeba/img_align_celeba/198248.jpg
#  extracting: img_align_celeba/img_align_celeba/198249.jpg
#  extracting: img_align_celeba/img_align_celeba/198250.jpg
#  extracting: img_align_celeba/img_align_celeba/198251.jpg
#  extracting: img_align_celeba/img_align_celeba/198252.jpg
#  extracting: img_align_celeba/img_align_celeba/198253.jpg
#  extracting: img_align_celeba/img_align_celeba/198254.jpg
#  extracting: img_align_celeba/img_align_celeba/198255.jpg
#  extracting: img_align_celeba/img_align_celeba/198256.jpg
#  extracting: img_align_celeba/img_align_celeba/198257.jpg
#  extracting: img_align_celeba/img_align_celeba/198258.jpg
#  extracting: img_align_celeba/img_align_celeba/198259.jpg
#  extracting: img_align_celeba/img_align_celeba/198260.jpg
#  extracting: img_align_celeba/img_align_celeba/198261.jpg
#  extracting: img_align_celeba/img_align_celeba/198262.jpg
#  extracting: img_align_celeba/img_align_celeba/198263.jpg
#  extracting: img_align_celeba/img_align_celeba/198264.jpg
#  extracting: img_align_celeba/img_align_celeba/198265.jpg
#  extracting: img_align_celeba/img_align_celeba/198266.jpg
#  extracting: img_align_celeba/img_align_celeba/198267.jpg
#  extracting: img_align_celeba/img_align_celeba/198268.jpg
#  extracting: img_align_celeba/img_align_celeba/198269.jpg
#  extracting: img_align_celeba/img_align_celeba/198270.jpg
#  extracting: img_align_celeba/img_align_celeba/198271.jpg
#  extracting: img_align_celeba/img_align_celeba/198272.jpg
#  extracting: img_align_celeba/img_align_celeba/198273.jpg
#  extracting: img_align_celeba/img_align_celeba/198274.jpg
#  extracting: img_align_celeba/img_align_celeba/198275.jpg
#  extracting: img_align_celeba/img_align_celeba/198276.jpg
#  extracting: img_align_celeba/img_align_celeba/198277.jpg
#  extracting: img_align_celeba/img_align_celeba/198278.jpg
#  extracting: img_align_celeba/img_align_celeba/198279.jpg
#  extracting: img_align_celeba/img_align_celeba/198280.jpg
#  extracting: img_align_celeba/img_align_celeba/198281.jpg
#  extracting: img_align_celeba/img_align_celeba/198282.jpg
#  extracting: img_align_celeba/img_align_celeba/198283.jpg
#  extracting: img_align_celeba/img_align_celeba/198284.jpg
#  extracting: img_align_celeba/img_align_celeba/198285.jpg
#  extracting: img_align_celeba/img_align_celeba/198286.jpg
#  extracting: img_align_celeba/img_align_celeba/198287.jpg
#  extracting: img_align_celeba/img_align_celeba/198288.jpg
#  extracting: img_align_celeba/img_align_celeba/198289.jpg
#  extracting: img_align_celeba/img_align_celeba/198290.jpg
#  extracting: img_align_celeba/img_align_celeba/198291.jpg
#  extracting: img_align_celeba/img_align_celeba/198292.jpg
#  extracting: img_align_celeba/img_align_celeba/198293.jpg
#  extracting: img_align_celeba/img_align_celeba/198294.jpg
#  extracting: img_align_celeba/img_align_celeba/198295.jpg
#  extracting: img_align_celeba/img_align_celeba/198296.jpg
#  extracting: img_align_celeba/img_align_celeba/198297.jpg
#  extracting: img_align_celeba/img_align_celeba/198298.jpg
#  extracting: img_align_celeba/img_align_celeba/198299.jpg
#  extracting: img_align_celeba/img_align_celeba/198300.jpg
#  extracting: img_align_celeba/img_align_celeba/198301.jpg
#  extracting: img_align_celeba/img_align_celeba/198302.jpg
#  extracting: img_align_celeba/img_align_celeba/198303.jpg
#  extracting: img_align_celeba/img_align_celeba/198304.jpg
#  extracting: img_align_celeba/img_align_celeba/198305.jpg
#  extracting: img_align_celeba/img_align_celeba/198306.jpg
#  extracting: img_align_celeba/img_align_celeba/198307.jpg
#  extracting: img_align_celeba/img_align_celeba/198308.jpg
#  extracting: img_align_celeba/img_align_celeba/198309.jpg
#  extracting: img_align_celeba/img_align_celeba/198310.jpg
#  extracting: img_align_celeba/img_align_celeba/198311.jpg
#  extracting: img_align_celeba/img_align_celeba/198312.jpg
#  extracting: img_align_celeba/img_align_celeba/198313.jpg
#  extracting: img_align_celeba/img_align_celeba/198314.jpg
#  extracting: img_align_celeba/img_align_celeba/198315.jpg
#  extracting: img_align_celeba/img_align_celeba/198316.jpg
#  extracting: img_align_celeba/img_align_celeba/198317.jpg
#  extracting: img_align_celeba/img_align_celeba/198318.jpg
#  extracting: img_align_celeba/img_align_celeba/198319.jpg
#  extracting: img_align_celeba/img_align_celeba/198320.jpg
#  extracting: img_align_celeba/img_align_celeba/198321.jpg
#  extracting: img_align_celeba/img_align_celeba/198322.jpg
#  extracting: img_align_celeba/img_align_celeba/198323.jpg
#  extracting: img_align_celeba/img_align_celeba/198324.jpg
#  extracting: img_align_celeba/img_align_celeba/198325.jpg
#  extracting: img_align_celeba/img_align_celeba/198326.jpg
#  extracting: img_align_celeba/img_align_celeba/198327.jpg
#  extracting: img_align_celeba/img_align_celeba/198328.jpg
#  extracting: img_align_celeba/img_align_celeba/198329.jpg
#  extracting: img_align_celeba/img_align_celeba/198330.jpg
#  extracting: img_align_celeba/img_align_celeba/198331.jpg
#  extracting: img_align_celeba/img_align_celeba/198332.jpg
#  extracting: img_align_celeba/img_align_celeba/198333.jpg
#  extracting: img_align_celeba/img_align_celeba/198334.jpg
#  extracting: img_align_celeba/img_align_celeba/198335.jpg
#  extracting: img_align_celeba/img_align_celeba/198336.jpg
#  extracting: img_align_celeba/img_align_celeba/198337.jpg
#  extracting: img_align_celeba/img_align_celeba/198338.jpg
#  extracting: img_align_celeba/img_align_celeba/198339.jpg
#  extracting: img_align_celeba/img_align_celeba/198340.jpg
#  extracting: img_align_celeba/img_align_celeba/198341.jpg
#  extracting: img_align_celeba/img_align_celeba/198342.jpg
#  extracting: img_align_celeba/img_align_celeba/198343.jpg
#  extracting: img_align_celeba/img_align_celeba/198344.jpg
#  extracting: img_align_celeba/img_align_celeba/198345.jpg
#  extracting: img_align_celeba/img_align_celeba/198346.jpg
#  extracting: img_align_celeba/img_align_celeba/198347.jpg
#  extracting: img_align_celeba/img_align_celeba/198348.jpg
#  extracting: img_align_celeba/img_align_celeba/198349.jpg
#  extracting: img_align_celeba/img_align_celeba/198350.jpg
#  extracting: img_align_celeba/img_align_celeba/198351.jpg
#  extracting: img_align_celeba/img_align_celeba/198352.jpg
#  extracting: img_align_celeba/img_align_celeba/198353.jpg
#  extracting: img_align_celeba/img_align_celeba/198354.jpg
#  extracting: img_align_celeba/img_align_celeba/198355.jpg
#  extracting: img_align_celeba/img_align_celeba/198356.jpg
#  extracting: img_align_celeba/img_align_celeba/198357.jpg
#  extracting: img_align_celeba/img_align_celeba/198358.jpg
#  extracting: img_align_celeba/img_align_celeba/198359.jpg
#  extracting: img_align_celeba/img_align_celeba/198360.jpg
#  extracting: img_align_celeba/img_align_celeba/198361.jpg
#  extracting: img_align_celeba/img_align_celeba/198362.jpg
#  extracting: img_align_celeba/img_align_celeba/198363.jpg
#  extracting: img_align_celeba/img_align_celeba/198364.jpg
#  extracting: img_align_celeba/img_align_celeba/198365.jpg
#  extracting: img_align_celeba/img_align_celeba/198366.jpg
#  extracting: img_align_celeba/img_align_celeba/198367.jpg
#  extracting: img_align_celeba/img_align_celeba/198368.jpg
#  extracting: img_align_celeba/img_align_celeba/198369.jpg
#  extracting: img_align_celeba/img_align_celeba/198370.jpg
#  extracting: img_align_celeba/img_align_celeba/198371.jpg
#  extracting: img_align_celeba/img_align_celeba/198372.jpg
#  extracting: img_align_celeba/img_align_celeba/198373.jpg
#  extracting: img_align_celeba/img_align_celeba/198374.jpg
#  extracting: img_align_celeba/img_align_celeba/198375.jpg
#  extracting: img_align_celeba/img_align_celeba/198376.jpg
#  extracting: img_align_celeba/img_align_celeba/198377.jpg
#  extracting: img_align_celeba/img_align_celeba/198378.jpg
#  extracting: img_align_celeba/img_align_celeba/198379.jpg
#  extracting: img_align_celeba/img_align_celeba/198380.jpg
#  extracting: img_align_celeba/img_align_celeba/198381.jpg
#  extracting: img_align_celeba/img_align_celeba/198382.jpg
#  extracting: img_align_celeba/img_align_celeba/198383.jpg
#  extracting: img_align_celeba/img_align_celeba/198384.jpg
#  extracting: img_align_celeba/img_align_celeba/198385.jpg
#  extracting: img_align_celeba/img_align_celeba/198386.jpg
#  extracting: img_align_celeba/img_align_celeba/198387.jpg
#  extracting: img_align_celeba/img_align_celeba/198388.jpg
#  extracting: img_align_celeba/img_align_celeba/198389.jpg
#  extracting: img_align_celeba/img_align_celeba/198390.jpg
#  extracting: img_align_celeba/img_align_celeba/198391.jpg
#  extracting: img_align_celeba/img_align_celeba/198392.jpg
#  extracting: img_align_celeba/img_align_celeba/198393.jpg
#  extracting: img_align_celeba/img_align_celeba/198394.jpg
#  extracting: img_align_celeba/img_align_celeba/198395.jpg
#  extracting: img_align_celeba/img_align_celeba/198396.jpg
#  extracting: img_align_celeba/img_align_celeba/198397.jpg
#  extracting: img_align_celeba/img_align_celeba/198398.jpg
# ...
#  extracting: img_align_celeba/img_align_celeba/202334.jpg
#  extracting: img_align_celeba/img_align_celeba/202335.jpg
#  extracting: img_align_celeba/img_align_celeba/202336.jpg
#  extracting: img_align_celeba/img_align_celeba/202337.jpg
#  extracting: img_align_celeba/img_align_celeba/202338.jpg
#  extracting: img_align_celeba/img_align_celeba/202339.jpg
#  extracting: img_align_celeba/img_align_celeba/202340.jpg
#  extracting: img_align_celeba/img_align_celeba/202341.jpg
#  extracting: img_align_celeba/img_align_celeba/202342.jpg
#  extracting: img_align_celeba/img_align_celeba/202343.jpg
#  extracting: img_align_celeba/img_align_celeba/202344.jpg
#  extracting: img_align_celeba/img_align_celeba/202345.jpg
#  extracting: img_align_celeba/img_align_celeba/202346.jpg
#  extracting: img_align_celeba/img_align_celeba/202347.jpg
#  extracting: img_align_celeba/img_align_celeba/202348.jpg
#  extracting: img_align_celeba/img_align_celeba/202349.jpg
#  extracting: img_align_celeba/img_align_celeba/202350.jpg
#  extracting: img_align_celeba/img_align_celeba/202351.jpg
#  extracting: img_align_celeba/img_align_celeba/202352.jpg
#  extracting: img_align_celeba/img_align_celeba/202353.jpg
#  extracting: img_align_celeba/img_align_celeba/202354.jpg
#  extracting: img_align_celeba/img_align_celeba/202355.jpg
#  extracting: img_align_celeba/img_align_celeba/202356.jpg
#  extracting: img_align_celeba/img_align_celeba/202357.jpg
#  extracting: img_align_celeba/img_align_celeba/202358.jpg
#  extracting: img_align_celeba/img_align_celeba/202359.jpg
#  extracting: img_align_celeba/img_align_celeba/202360.jpg
#  extracting: img_align_celeba/img_align_celeba/202361.jpg
#  extracting: img_align_celeba/img_align_celeba/202362.jpg
#  extracting: img_align_celeba/img_align_celeba/202363.jpg
#  extracting: img_align_celeba/img_align_celeba/202364.jpg
#  extracting: img_align_celeba/img_align_celeba/202365.jpg
#  extracting: img_align_celeba/img_align_celeba/202366.jpg
#  extracting: img_align_celeba/img_align_celeba/202367.jpg
#  extracting: img_align_celeba/img_align_celeba/202368.jpg
#  extracting: img_align_celeba/img_align_celeba/202369.jpg
#  extracting: img_align_celeba/img_align_celeba/202370.jpg
#  extracting: img_align_celeba/img_align_celeba/202371.jpg
#  extracting: img_align_celeba/img_align_celeba/202372.jpg
#  extracting: img_align_celeba/img_align_celeba/202373.jpg
#  extracting: img_align_celeba/img_align_celeba/202374.jpg
#  extracting: img_align_celeba/img_align_celeba/202375.jpg
#  extracting: img_align_celeba/img_align_celeba/202376.jpg
#  extracting: img_align_celeba/img_align_celeba/202377.jpg
#  extracting: img_align_celeba/img_align_celeba/202378.jpg
#  extracting: img_align_celeba/img_align_celeba/202379.jpg
#  extracting: img_align_celeba/img_align_celeba/202380.jpg
#  extracting: img_align_celeba/img_align_celeba/202381.jpg
#  extracting: img_align_celeba/img_align_celeba/202382.jpg
#  extracting: img_align_celeba/img_align_celeba/202383.jpg
#  extracting: img_align_celeba/img_align_celeba/202384.jpg
#  extracting: img_align_celeba/img_align_celeba/202385.jpg
#  extracting: img_align_celeba/img_align_celeba/202386.jpg
#  extracting: img_align_celeba/img_align_celeba/202387.jpg
#  extracting: img_align_celeba/img_align_celeba/202388.jpg
#  extracting: img_align_celeba/img_align_celeba/202389.jpg
#  extracting: img_align_celeba/img_align_celeba/202390.jpg
#  extracting: img_align_celeba/img_align_celeba/202391.jpg
#  extracting: img_align_celeba/img_align_celeba/202392.jpg
#  extracting: img_align_celeba/img_align_celeba/202393.jpg
#  extracting: img_align_celeba/img_align_celeba/202394.jpg
#  extracting: img_align_celeba/img_align_celeba/202395.jpg
#  extracting: img_align_celeba/img_align_celeba/202396.jpg
#  extracting: img_align_celeba/img_align_celeba/202397.jpg
#  extracting: img_align_celeba/img_align_celeba/202398.jpg
#  extracting: img_align_celeba/img_align_celeba/202399.jpg
#  extracting: img_align_celeba/img_align_celeba/202400.jpg
#  extracting: img_align_celeba/img_align_celeba/202401.jpg
#  extracting: img_align_celeba/img_align_celeba/202402.jpg
#  extracting: img_align_celeba/img_align_celeba/202403.jpg
#  extracting: img_align_celeba/img_align_celeba/202404.jpg
#  extracting: img_align_celeba/img_align_celeba/202405.jpg
#  extracting: img_align_celeba/img_align_celeba/202406.jpg
#  extracting: img_align_celeba/img_align_celeba/202407.jpg
#  extracting: img_align_celeba/img_align_celeba/202408.jpg
#  extracting: img_align_celeba/img_align_celeba/202409.jpg
#  extracting: img_align_celeba/img_align_celeba/202410.jpg
#  extracting: img_align_celeba/img_align_celeba/202411.jpg
#  extracting: img_align_celeba/img_align_celeba/202412.jpg
#  extracting: img_align_celeba/img_align_celeba/202413.jpg
#  extracting: img_align_celeba/img_align_celeba/202414.jpg
#  extracting: img_align_celeba/img_align_celeba/202415.jpg
#  extracting: img_align_celeba/img_align_celeba/202416.jpg
#  extracting: img_align_celeba/img_align_celeba/202417.jpg
#  extracting: img_align_celeba/img_align_celeba/202418.jpg
#  extracting: img_align_celeba/img_align_celeba/202419.jpg
#  extracting: img_align_celeba/img_align_celeba/202420.jpg
#  extracting: img_align_celeba/img_align_celeba/202421.jpg
#  extracting: img_align_celeba/img_align_celeba/202422.jpg
#  extracting: img_align_celeba/img_align_celeba/202423.jpg
#  extracting: img_align_celeba/img_align_celeba/202424.jpg
#  extracting: img_align_celeba/img_align_celeba/202425.jpg
#  extracting: img_align_celeba/img_align_celeba/202426.jpg
#  extracting: img_align_celeba/img_align_celeba/202427.jpg
#  extracting: img_align_celeba/img_align_celeba/202428.jpg
#  extracting: img_align_celeba/img_align_celeba/202429.jpg
#  extracting: img_align_celeba/img_align_celeba/202430.jpg
#  extracting: img_align_celeba/img_align_celeba/202431.jpg
#  extracting: img_align_celeba/img_align_celeba/202432.jpg
#  extracting: img_align_celeba/img_align_celeba/202433.jpg
#  extracting: img_align_celeba/img_align_celeba/202434.jpg
#  extracting: img_align_celeba/img_align_celeba/202435.jpg
#  extracting: img_align_celeba/img_align_celeba/202436.jpg
#  extracting: img_align_celeba/img_align_celeba/202437.jpg
#  extracting: img_align_celeba/img_align_celeba/202438.jpg
#  extracting: img_align_celeba/img_align_celeba/202439.jpg
#  extracting: img_align_celeba/img_align_celeba/202440.jpg
#  extracting: img_align_celeba/img_align_celeba/202441.jpg
#  extracting: img_align_celeba/img_align_celeba/202442.jpg
#  extracting: img_align_celeba/img_align_celeba/202443.jpg
#  extracting: img_align_celeba/img_align_celeba/202444.jpg
#  extracting: img_align_celeba/img_align_celeba/202445.jpg
#  extracting: img_align_celeba/img_align_celeba/202446.jpg
#  extracting: img_align_celeba/img_align_celeba/202447.jpg
#  extracting: img_align_celeba/img_align_celeba/202448.jpg
#  extracting: img_align_celeba/img_align_celeba/202449.jpg
#  extracting: img_align_celeba/img_align_celeba/202450.jpg
#  extracting: img_align_celeba/img_align_celeba/202451.jpg
#  extracting: img_align_celeba/img_align_celeba/202452.jpg
#  extracting: img_align_celeba/img_align_celeba/202453.jpg
#  extracting: img_align_celeba/img_align_celeba/202454.jpg
#  extracting: img_align_celeba/img_align_celeba/202455.jpg
#  extracting: img_align_celeba/img_align_celeba/202456.jpg
#  extracting: img_align_celeba/img_align_celeba/202457.jpg
#  extracting: img_align_celeba/img_align_celeba/202458.jpg
#  extracting: img_align_celeba/img_align_celeba/202459.jpg
#  extracting: img_align_celeba/img_align_celeba/202460.jpg
#  extracting: img_align_celeba/img_align_celeba/202461.jpg
#  extracting: img_align_celeba/img_align_celeba/202462.jpg
#  extracting: img_align_celeba/img_align_celeba/202463.jpg
#  extracting: img_align_celeba/img_align_celeba/202464.jpg
#  extracting: img_align_celeba/img_align_celeba/202465.jpg
#  extracting: img_align_celeba/img_align_celeba/202466.jpg
#  extracting: img_align_celeba/img_align_celeba/202467.jpg
#  extracting: img_align_celeba/img_align_celeba/202468.jpg
#  extracting: img_align_celeba/img_align_celeba/202469.jpg
#  extracting: img_align_celeba/img_align_celeba/202470.jpg
#  extracting: img_align_celeba/img_align_celeba/202471.jpg
#  extracting: img_align_celeba/img_align_celeba/202472.jpg
#  extracting: img_align_celeba/img_align_celeba/202473.jpg
#  extracting: img_align_celeba/img_align_celeba/202474.jpg
#  extracting: img_align_celeba/img_align_celeba/202475.jpg
#  extracting: img_align_celeba/img_align_celeba/202476.jpg
#  extracting: img_align_celeba/img_align_celeba/202477.jpg
#  extracting: img_align_celeba/img_align_celeba/202478.jpg
#  extracting: img_align_celeba/img_align_celeba/202479.jpg
#  extracting: img_align_celeba/img_align_celeba/202480.jpg
#  extracting: img_align_celeba/img_align_celeba/202481.jpg
#  extracting: img_align_celeba/img_align_celeba/202482.jpg
#  extracting: img_align_celeba/img_align_celeba/202483.jpg
#  extracting: img_align_celeba/img_align_celeba/202484.jpg
#  extracting: img_align_celeba/img_align_celeba/202485.jpg
#  extracting: img_align_celeba/img_align_celeba/202486.jpg
#  extracting: img_align_celeba/img_align_celeba/202487.jpg
#  extracting: img_align_celeba/img_align_celeba/202488.jpg
#  extracting: img_align_celeba/img_align_celeba/202489.jpg
#  extracting: img_align_celeba/img_align_celeba/202490.jpg
#  extracting: img_align_celeba/img_align_celeba/202491.jpg
#  extracting: img_align_celeba/img_align_celeba/202492.jpg
#  extracting: img_align_celeba/img_align_celeba/202493.jpg
#  extracting: img_align_celeba/img_align_celeba/202494.jpg
#  extracting: img_align_celeba/img_align_celeba/202495.jpg
#  extracting: img_align_celeba/img_align_celeba/202496.jpg
#  extracting: img_align_celeba/img_align_celeba/202497.jpg
#  extracting: img_align_celeba/img_align_celeba/202498.jpg
#  extracting: img_align_celeba/img_align_celeba/202499.jpg
#  extracting: img_align_celeba/img_align_celeba/202500.jpg
#  extracting: img_align_celeba/img_align_celeba/202501.jpg
#  extracting: img_align_celeba/img_align_celeba/202502.jpg
#  extracting: img_align_celeba/img_align_celeba/202503.jpg
#  extracting: img_align_celeba/img_align_celeba/202504.jpg
#  extracting: img_align_celeba/img_align_celeba/202505.jpg
#  extracting: img_align_celeba/img_align_celeba/202506.jpg
#  extracting: img_align_celeba/img_align_celeba/202507.jpg
#  extracting: img_align_celeba/img_align_celeba/202508.jpg
#  extracting: img_align_celeba/img_align_celeba/202509.jpg
#  extracting: img_align_celeba/img_align_celeba/202510.jpg
#  extracting: img_align_celeba/img_align_celeba/202511.jpg
#  extracting: img_align_celeba/img_align_celeba/202512.jpg
#  extracting: img_align_celeba/img_align_celeba/202513.jpg
#  extracting: img_align_celeba/img_align_celeba/202514.jpg
#  extracting: img_align_celeba/img_align_celeba/202515.jpg
#  extracting: img_align_celeba/img_align_celeba/202516.jpg
#  extracting: img_align_celeba/img_align_celeba/202517.jpg
#  extracting: img_align_celeba/img_align_celeba/202518.jpg
#  extracting: img_align_celeba/img_align_celeba/202519.jpg
#  extracting: img_align_celeba/img_align_celeba/202520.jpg
#  extracting: img_align_celeba/img_align_celeba/202521.jpg
#  extracting: img_align_celeba/img_align_celeba/202522.jpg
#  extracting: img_align_celeba/img_align_celeba/202523.jpg
#  extracting: img_align_celeba/img_align_celeba/202524.jpg
#  extracting: img_align_celeba/img_align_celeba/202525.jpg
#  extracting: img_align_celeba/img_align_celeba/202526.jpg
#  extracting: img_align_celeba/img_align_celeba/202527.jpg
#  extracting: img_align_celeba/img_align_celeba/202528.jpg
#  extracting: img_align_celeba/img_align_celeba/202529.jpg
#  extracting: img_align_celeba/img_align_celeba/202530.jpg
#  extracting: img_align_celeba/img_align_celeba/202531.jpg
#  extracting: img_align_celeba/img_align_celeba/202532.jpg
#  extracting: img_align_celeba/img_align_celeba/202533.jpg
#  extracting: img_align_celeba/img_align_celeba/202534.jpg
#  extracting: img_align_celeba/img_align_celeba/202535.jpg
#  extracting: img_align_celeba/img_align_celeba/202536.jpg
#  extracting: img_align_celeba/img_align_celeba/202537.jpg
#  extracting: img_align_celeba/img_align_celeba/202538.jpg
#  extracting: img_align_celeba/img_align_celeba/202539.jpg
#  extracting: img_align_celeba/img_align_celeba/202540.jpg
#  extracting: img_align_celeba/img_align_celeba/202541.jpg
#  extracting: img_align_celeba/img_align_celeba/202542.jpg
#  extracting: img_align_celeba/img_align_celeba/202543.jpg
#  extracting: img_align_celeba/img_align_celeba/202544.jpg
#  extracting: img_align_celeba/img_align_celeba/202545.jpg
#  extracting: img_align_celeba/img_align_celeba/202546.jpg
#  extracting: img_align_celeba/img_align_celeba/202547.jpg
#  extracting: img_align_celeba/img_align_celeba/202548.jpg
#  extracting: img_align_celeba/img_align_celeba/202549.jpg
#  extracting: img_align_celeba/img_align_celeba/202550.jpg
#  extracting: img_align_celeba/img_align_celeba/202551.jpg
#  extracting: img_align_celeba/img_align_celeba/202552.jpg
#  extracting: img_align_celeba/img_align_celeba/202553.jpg
#  extracting: img_align_celeba/img_align_celeba/202554.jpg
#  extracting: img_align_celeba/img_align_celeba/202555.jpg
#  extracting: img_align_celeba/img_align_celeba/202556.jpg
#  extracting: img_align_celeba/img_align_celeba/202557.jpg
#  extracting: img_align_celeba/img_align_celeba/202558.jpg
#  extracting: img_align_celeba/img_align_celeba/202559.jpg
#  extracting: img_align_celeba/img_align_celeba/202560.jpg
#  extracting: img_align_celeba/img_align_celeba/202561.jpg
#  extracting: img_align_celeba/img_align_celeba/202562.jpg
#  extracting: img_align_celeba/img_align_celeba/202563.jpg
#  extracting: img_align_celeba/img_align_celeba/202564.jpg
#  extracting: img_align_celeba/img_align_celeba/202565.jpg
#  extracting: img_align_celeba/img_align_celeba/202566.jpg
#  extracting: img_align_celeba/img_align_celeba/202567.jpg
#  extracting: img_align_celeba/img_align_celeba/202568.jpg
#  extracting: img_align_celeba/img_align_celeba/202569.jpg
#  extracting: img_align_celeba/img_align_celeba/202570.jpg
#  extracting: img_align_celeba/img_align_celeba/202571.jpg
#  extracting: img_align_celeba/img_align_celeba/202572.jpg
#  extracting: img_align_celeba/img_align_celeba/202573.jpg
#  extracting: img_align_celeba/img_align_celeba/202574.jpg
#  extracting: img_align_celeba/img_align_celeba/202575.jpg
#  extracting: img_align_celeba/img_align_celeba/202576.jpg
#  extracting: img_align_celeba/img_align_celeba/202577.jpg
#  extracting: img_align_celeba/img_align_celeba/202578.jpg
#  extracting: img_align_celeba/img_align_celeba/202579.jpg
#  extracting: img_align_celeba/img_align_celeba/202580.jpg
#  extracting: img_align_celeba/img_align_celeba/202581.jpg
#  extracting: img_align_celeba/img_align_celeba/202582.jpg
#  extracting: img_align_celeba/img_align_celeba/202583.jpg
#  extracting: img_align_celeba/img_align_celeba/202584.jpg
#  extracting: img_align_celeba/img_align_celeba/202585.jpg
#  extracting: img_align_celeba/img_align_celeba/202586.jpg
#  extracting: img_align_celeba/img_align_celeba/202587.jpg
#  extracting: img_align_celeba/img_align_celeba/202588.jpg
#  extracting: img_align_celeba/img_align_celeba/202589.jpg
#  extracting: img_align_celeba/img_align_celeba/202590.jpg
#  extracting: img_align_celeba/img_align_celeba/202591.jpg
#  extracting: img_align_celeba/img_align_celeba/202592.jpg
#  extracting: img_align_celeba/img_align_celeba/202593.jpg
#  extracting: img_align_celeba/img_align_celeba/202594.jpg
#  extracting: img_align_celeba/img_align_celeba/202595.jpg
#  extracting: img_align_celeba/img_align_celeba/202596.jpg
#  extracting: img_align_celeba/img_align_celeba/202597.jpg
#  extracting: img_align_celeba/img_align_celeba/202598.jpg
#  extracting: img_align_celeba/img_align_celeba/202599.jpg

# %% [markdown]
# # Create Custom Datset Class

# %%
class CelebADataset(Dataset):
    def __init__(self, img_dir, attr_path, transform=None):
        self.img_dir = img_dir
        self.transform = transform
        self.attrs = self.load_attributes(attr_path)
        self.imgs = sorted(os.listdir(self.img_dir))  # Ensure sorted to match the attribute file order

    def load_attributes(self, attr_path):
        with open(attr_path, 'r') as f:
            lines = f.readlines()
            attr_names = lines[1].split()
            attrs = {}
            for line in lines[2:]:
                parts = line.split()
                img_name = parts[0]
                # Convert -1 to 0 in the attributes
                attr_values = [0 if int(x) == -1 else 1 for x in parts[1:]]
                attrs[img_name] = torch.tensor(attr_values, dtype=torch.float32)
        return attrs

    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, idx):
        img_name = self.imgs[idx]
        img_path = os.path.join(self.img_dir, img_name)
        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        attributes = self.attrs[img_name]
        return image, attributes

# %% [markdown]
# # Create the Dataset and the Dataloader

# %%
# Dataset and DataLoader
dataset = CelebADataset(img_dir='img_align_celeba/img_align_celeba', attr_path='list_attr_celeba.txt', transform=transform)
dataloader = DataLoader(dataset, batch_size=64, shuffle=True, num_workers= 4)

# %%
# Verify the data loading
dataiter = iter(dataloader)
images, labels = next(dataiter)
print(images.shape)
print(labels.shape)
# Out:
# torch.Size([64, 3, 64, 64])
# torch.Size([64, 40])

# %% [markdown]
# # Visualizing some sample images

# %%
# Visualizing some sample images
figure = plt.figure(figsize=(14, 14))
cols, rows = 2, 1
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(dataset), size=(1,)).item()
    img, label = dataset[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(label)
    plt.axis("off")
    plt.imshow(img.permute(1, 2, 0))  # Change to permute to display RGB images correctly
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
from typing import List, Callable, Union, Any, TypeVar, Tuple
from torch import nn
from abc import abstractmethod
from torch.nn import functional as F

Tensor = TypeVar('torch.tensor')

# %% [markdown]
# # Conditional VAE Model Archeticture

# %%
class BaseVAE(nn.Module):
    def __init__(self) -> None:
        super(BaseVAE, self).__init__()

    def encode(self, input: Tensor) -> List[Tensor]:
        raise NotImplementedError

    def decode(self, input: Tensor) -> Any:
        raise NotImplementedError

    def sample(self, batch_size:int, current_device: device, **kwargs) -> Tensor:
        raise NotImplementedError

    def generate(self, x: Tensor, **kwargs) -> Tensor:
        raise NotImplementedError

    @abstractmethod
    def forward(self, *inputs: Tensor) -> Tensor:
        pass

    @abstractmethod
    def loss_function(self, *inputs: Any, **kwargs) -> Tensor:
        pass

# %%
class ConditionalVAE(BaseVAE):

    def __init__(self,
                 in_channels: int,
                 num_classes: int,
                 latent_dim: int,
                 hidden_dims: List = None,
                 img_size:int = 64,
                 **kwargs) -> None:
        super(ConditionalVAE, self).__init__()

        self.latent_dim = latent_dim
        self.img_size = img_size

        self.embed_class = nn.Linear(num_classes, img_size * img_size)
        self.embed_data = nn.Conv2d(in_channels, in_channels, kernel_size=1)

        modules = []
        if hidden_dims is None:
            hidden_dims = [32, 64, 128, 256, 512]

        in_channels += 1 # To account for the extra label channel
        # Build Encoder
        for h_dim in hidden_dims:
            modules.append(
                nn.Sequential(
                    nn.Conv2d(in_channels, out_channels=h_dim,
                              kernel_size= 3, stride= 2, padding  = 1),
                    nn.BatchNorm2d(h_dim),
                    nn.LeakyReLU())
            )
            in_channels = h_dim

        self.encoder = nn.Sequential(*modules)
        self.fc_mu = nn.Linear(hidden_dims[-1]*4, latent_dim)
        self.fc_var = nn.Linear(hidden_dims[-1]*4, latent_dim)


        # Build Decoder
        modules = []

        self.decoder_input = nn.Linear(latent_dim + num_classes, hidden_dims[-1] * 4)

        hidden_dims.reverse()

        for i in range(len(hidden_dims) - 1):
            modules.append(
                nn.Sequential(
                    nn.ConvTranspose2d(hidden_dims[i],
                                       hidden_dims[i + 1],
                                       kernel_size=3,
                                       stride = 2,
                                       padding=1,
                                       output_padding=1),
                    nn.BatchNorm2d(hidden_dims[i + 1]),
                    nn.LeakyReLU())
            )



        self.decoder = nn.Sequential(*modules)

        self.final_layer = nn.Sequential(
                            nn.ConvTranspose2d(hidden_dims[-1],
                                               hidden_dims[-1],
                                               kernel_size=3,
                                               stride=2,
                                               padding=1,
                                               output_padding=1),
                            nn.BatchNorm2d(hidden_dims[-1]),
                            nn.LeakyReLU(),
                            nn.Conv2d(hidden_dims[-1], out_channels= 3,
                                      kernel_size= 3, padding= 1),
                            nn.Tanh())

    def encode(self, input: Tensor) -> List[Tensor]:
        """
        Encodes the input by passing through the encoder network
        and returns the latent codes.
        :param input: (Tensor) Input tensor to encoder [N x C x H x W]
        :return: (Tensor) List of latent codes
        """
        result = self.encoder(input)
        result = torch.flatten(result, start_dim=1)

        # Split the result into mu and var components
        # of the latent Gaussian distribution
        mu = self.fc_mu(result)
        log_var = self.fc_var(result)

        return [mu, log_var]

    def decode(self, z: Tensor) -> Tensor:
        result = self.decoder_input(z)
        result = result.view(-1, 512, 2, 2)
        result = self.decoder(result)
        result = self.final_layer(result)
        return result

    def reparameterize(self, mu: Tensor, logvar: Tensor) -> Tensor:
        """
        Will a single z be enough to compute the expectation
        for the loss??
        :param mu: (Tensor) Mean of the latent Gaussian
        :param logvar: (Tensor) Standard deviation of the latent Gaussian
        :return:
        """
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return eps * std + mu

    def forward(self, input: Tensor, **kwargs) -> List[Tensor]:
        y = kwargs['labels'].float().to(input.device)  # Ensure labels are on the same device
        embedded_class = self.embed_class(y)
        embedded_class = embedded_class.view(-1, self.img_size, self.img_size).unsqueeze(1).to(input.device)
        embedded_input = self.embed_data(input)

        x = torch.cat([embedded_input, embedded_class], dim = 1)
        mu, log_var = self.encode(x)

        z = self.reparameterize(mu, log_var)

        z = torch.cat([z, y], dim = 1)
        return  [self.decode(z), input, mu, log_var]

    def loss_function(self,
                      *args,
                      **kwargs) -> dict:
        recons = args[0]
        input = args[1]
        mu = args[2]
        log_var = args[3]

        kld_weight = kwargs['M_N']
        recons_loss =F.mse_loss(recons, input)

        kld_loss = torch.mean(-0.5 * torch.sum(1 + log_var - mu ** 2 - log_var.exp(), dim = 1), dim = 0)

        loss = recons_loss + kld_weight * kld_loss
        return {'loss': loss, 'Reconstruction_Loss':recons_loss, 'KLD':-kld_loss}

    def sample(self,
               num_samples:int,
               current_device: int,
               **kwargs) -> Tensor:
        """
        Samples from the latent space and return the corresponding
        image space map.
        :param num_samples: (Int) Number of samples
        :param current_device: (Int) Device to run the model
        :return: (Tensor)
        """
        y = kwargs['labels'].float().to(current_device)  # Ensure labels are on the correct device
        z = torch.randn(num_samples,
                        self.latent_dim).to(current_device)

        z = torch.cat([z, y], dim=1)
        samples = self.decode(z)
        return samples

    def generate(self, x: Tensor, **kwargs) -> Tensor:
        """
        Given an input image x, returns the reconstructed image
        :param x: (Tensor) [B x C x H x W]
        :return: (Tensor) [B x C x H x W]
        """
        return self.forward(x, **kwargs)[0]

# %%
model = ConditionalVAE(in_channels=3, num_classes=40, latent_dim=128, hidden_dims=[32, 64, 128, 256, 512]).to(device)
model
# Out:
# ConditionalVAE(
#   (embed_class): Linear(in_features=40, out_features=4096, bias=True)
#   (embed_data): Conv2d(3, 3, kernel_size=(1, 1), stride=(1, 1))
#   (encoder): Sequential(
#     (0): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (fc_mu): Linear(in_features=2048, out_features=128, bias=True)
#   (fc_var): Linear(in_features=2048, out_features=128, bias=True)
#   (decoder_input): Linear(in_features=168, out_features=2048, bias=True)
#   (decoder): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (2): Sequential(
#       (0): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (3): Sequential(
#       (0): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (final_layer): Sequential(
#     (0): ConvTranspose2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): Tanh()
#   )
# )

# %%
# Function to display images
def show_images(images, num_images=8):
    images = images[:num_images]
    images = images * 0.5 + 0.5  # Unnormalize from [-1, 1] to [0, 1]
    grid_img = torchvision.utils.make_grid(images, nrow=num_images)
    plt.imshow(grid_img.permute(1, 2, 0))
    plt.show()

# %% [markdown]
# # Hyperparameters

# %%
epochs = 30
batch_size = 64
learning_rate = 1e-3 #0.005
latent_dim = 128
num_classes = 40
image_size = 64
KLD_WEIGHT = 0.00025

# %% [markdown]
# # Initialize the model and the optimizer

# %%
# Initialize model, optimizer, and loss function
model = ConditionalVAE(in_channels=3, num_classes=num_classes, latent_dim=latent_dim).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# # Train the model

# %%
# Training loop
for epoch in range(epochs):
    model.train()
    train_loss = 0
    for batch_idx, (data, labels) in enumerate(dataloader):
        data = data.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        outputs = model(data, labels=labels)
        recon_images, input_images, mu, log_var = outputs
        loss_dict = model.loss_function(recon_images, input_images, mu, log_var, M_N=KLD_WEIGHT)
        loss = loss_dict['loss']
        loss.backward()
        train_loss += loss.item()
        optimizer.step()

    print(f"Epoch {epoch+1}, Loss: {train_loss/len(dataloader)}")

    # Generate and display images
    model.eval()
    with torch.no_grad():
        sample_labels = torch.eye(num_classes)[torch.randint(0, num_classes, (batch_size,))].to(device)
        generated_images = model.sample(batch_size, current_device=device, labels=sample_labels)
        show_images(generated_images.cpu())
# Out:
# Epoch 1, Loss: 0.059951199781756066
# Epoch 2, Loss: 0.0599337560810553
# Epoch 3, Loss: 0.06000350064836269
# Epoch 4, Loss: 0.05930124116382857
# Epoch 5, Loss: 0.05890958092009374
# Epoch 6, Loss: 0.05900551497127659
# Epoch 7, Loss: 0.05890081353601097
# Epoch 8, Loss: 0.05870326006308545
# Epoch 9, Loss: 0.05840502830958644
# Epoch 10, Loss: 0.058086318129947946
# Epoch 11, Loss: 0.0582482742737661
# Epoch 12, Loss: 0.057812452157453974
# Epoch 13, Loss: 0.05781021875928539
# Epoch 14, Loss: 0.05745744853923025
# Epoch 15, Loss: 0.05786649788939213
# Epoch 16, Loss: 0.057213772304875905
# Epoch 17, Loss: 0.05756916149064552
# Epoch 18, Loss: 0.05702303401952566
# Epoch 19, Loss: 0.05679248043790806
# Epoch 20, Loss: 0.056963962553314464
# Epoch 21, Loss: 0.056464403997673544
# Epoch 22, Loss: 0.05654259557409804
# Epoch 23, Loss: 0.05626736301206803
# Epoch 24, Loss: 0.05644342659922071
# Epoch 25, Loss: 0.05604420930089415
# Epoch 26, Loss: 0.0559510901685833
# Epoch 27, Loss: 0.0561767248364613
# Epoch 28, Loss: 0.055863864734306816
# Epoch 29, Loss: 0.055787542589413104
# Epoch 30, Loss: 0.05548325601185477

# %%
# Save the model weights
torch.save(model.state_dict(), 'conditional_vae.pth')

# %% [markdown]
# # Manipulate the attributes of the images and visualize the results

# %%
# Define a function to manipulate attributes
def manipulate_attributes(num_samples, num_classes, selected_attrs):
    """
    Generate one-hot encoded labels based on the selected attributes.

    Args:
        num_samples (int): Number of samples to generate.
        num_classes (int): Number of attributes.
        selected_attrs (dict): Dictionary where keys are attribute indices (0 to num_classes-1) and
                               values are either 0 or 1 indicating the desired state of the attribute.

    Returns:
        Tensor: One-hot encoded tensor of manipulated attributes.
    """
    labels = torch.zeros((num_samples, num_classes))
    for attr_idx, value in selected_attrs.items():
        labels[:, attr_idx] = value
    return labels

# %%
# List of all attribute names
attribute_names = [
    '5_o_Clock_Shadow', 'Arched_Eyebrows', 'Attractive', 'Bags_Under_Eyes', 'Bald', 'Bangs',
    'Big_Lips', 'Big_Nose', 'Black_Hair', 'Blond_Hair', 'Blurry', 'Brown_Hair', 'Bushy_Eyebrows',
    'Chubby', 'Double_Chin', 'Eyeglasses', 'Goatee', 'Gray_Hair', 'Heavy_Makeup', 'High_Cheekbones',
    'Male', 'Mouth_Slightly_Open', 'Mustache', 'Narrow_Eyes', 'No_Beard', 'Oval_Face', 'Pale_Skin',
    'Pointy_Nose', 'Receding_Hairline', 'Rosy_Cheeks', 'Sideburns', 'Smiling', 'Straight_Hair',
    'Wavy_Hair', 'Wearing_Earrings', 'Wearing_Hat', 'Wearing_Lipstick', 'Wearing_Necklace',
    'Wearing_Necktie', 'Young'
]

# Map attribute names to indices
attribute_indices = {name: idx for idx, name in enumerate(attribute_names)}

# %%
# Now, let's manipulate attributes and generate images
selected_attrs = {
    attribute_indices['Male']: 0,
    attribute_indices['Eyeglasses']: 1,
    attribute_indices['Blond_Hair']: 1,
    attribute_indices['Smiling']: 1,
    attribute_indices['Bald']: 0,
    # Add more attribute manipulations as needed
}

# Generate one-hot encoded labels for the manipulated attributes
num_samples = 3
manipulated_labels = manipulate_attributes(num_samples, num_classes, selected_attrs).to(device)

# Generate images with the manipulated attributes
model.eval()
with torch.no_grad():
    generated_images = model.sample(num_samples, current_device=device, labels=manipulated_labels)
    show_images(generated_images.cpu())
